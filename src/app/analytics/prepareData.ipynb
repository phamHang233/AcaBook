# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Users/ADMIN/Documents/project/AcaBook/src/assets/data.csv')
data
# Out:
#                                order_id                        product_id
# 0      db68ee136b9cb2c16d74fa11a7395e5d  64d33e6bd1b905a31c2f96f584e6a0c8  \
# 1      061b74bca735bb2c1953e40bc098101d  f8ea5fcf9c628485e01b9c3cf52728c2
# 2      061b74bca735bb2c1953e40bc098101d  f8ea5fcf9c628485e01b9c3cf52728c2
# 3      061b74bca735bb2c1953e40bc098101d  f8ea5fcf9c628485e01b9c3cf52728c2
# 4      061b74bca735bb2c1953e40bc098101d  f8ea5fcf9c628485e01b9c3cf52728c2
# ...                                 ...                               ...
# 49993  d9206b6df475ed69a1f7de7ecc2d9401  53b36df67ebb7c41585e8d54d6772e08
# 49994  a00c2705f34c2a1714b0f36b80ba8fe1  0152cb427657428c06633fce6d721da4
# 49995  954399f1952a1ac05b51b69077de29d1  c0704b7b41d23540e8576c5e84484dcb
# 49996  12222b95d3464440506ffeede2239765  e70b02b0b99965f2ff4341de50a35c5d
# 49997  d394b412b6d133b86365feb125056e5b  8844bd4b8ca8f93603694ca2bceb77e9
#
#       shipping_limit_date   price  freight_value  payment_sequential
# ...

# %%
#drop duplicate rows
data = data.drop_duplicates()
data.to_csv('C:/Users/ADMIN/Documents/project/AcaBook/src/assets/data.csv')
# Out:
# Running cells with 'c:\msys64\mingw64\bin\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import csv 
import json
import time

def csv_to_json(csvFilePath, jsonFilePath):
    jsonArray = []
      
    #read csv file
    with open(csvFilePath, encoding='utf-8') as csvf: 
        #load csv file data using csv library's dictionary reader
        csvReader = csv.DictReader(csvf) 

        #convert each csv row into python dict
        for row in csvReader: 
            #add this python dict to json array
            jsonArray.append(row)
  
    #convert python jsonArray to JSON String and write to file
    with open(jsonFilePath, 'w', encoding='utf-8') as jsonf: 
        jsonString = json.dumps(jsonArray, indent=4)
        jsonf.write(jsonString)
          
csvFilePath = 'C:/Users/ADMIN/Documents/project/AcaBook/src/assets/reviewdata.csv'
jsonFilePath = r'reviewdata.json'

start = time.perf_counter()
csv_to_json(csvFilePath, jsonFilePath)
finish = time.perf_counter()

print(f"Conversion 100.000 rows completed successfully in {finish - start:0.4f} seconds")
# Out:
# Conversion 100.000 rows completed successfully in 0.0305 seconds
